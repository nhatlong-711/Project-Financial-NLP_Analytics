# %%
import os
import sys
import re

# =========================================================
# 1. ÉP VERSION PYSPARK (PHẢI CHẠY ĐẦU TIÊN TRƯỚC KHI IMPORT)
# =========================================================
modules_to_remove = [mod for mod in sys.modules if mod.startswith('pyspark') or mod.startswith('py4j')]
for mod in modules_to_remove: 
    del sys.modules[mod]

sys.path = [p for p in sys.path if "/usr/local/spark" not in p]
if "PYTHONPATH" in os.environ: 
    del os.environ["PYTHONPATH"]
    
conda_site_packages = "/opt/conda/lib/python3.13/site-packages"
if conda_site_packages not in sys.path: 
    sys.path.insert(0, conda_site_packages)
    
os.environ["SPARK_HOME"] = os.path.join(conda_site_packages, "pyspark")
os.environ["PYSPARK_PYTHON"] = "python3"
os.environ["PYSPARK_DRIVER_PYTHON"] = "python3"


# =========================================================
# 2. BÂY GIỜ MỚI IMPORT PYSPARK VÀ KHỞI TẠO SESSION
# =========================================================
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, concat_ws, udf
from pyspark.sql.types import FloatType

spark = SparkSession.builder \
    .appName("VADER_lemmas_score_Pipeline") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262,org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.access.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.secret.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.my_catalog", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.my_catalog.type", "hadoop") \
    .config("spark.sql.catalog.my_catalog.warehouse", "s3a://raw-financial-data/iceberg_warehouse") \
    .getOrCreate()


# =========================================================
# 3. VÁ LỖI THỜI GIAN HADOOP
# =========================================================
hadoop_conf = spark._jsc.hadoopConfiguration()
iterator = hadoop_conf.iterator()
while iterator.hasNext():
    entry = iterator.next()
    val = str(entry.getValue()).strip().lower()
    match = re.fullmatch(r"(\d+)([smhd])", val)
    if match:
        num, unit = int(match.group(1)), match.group(2)
        ms_val = num * 1000 if unit == 's' else num * 60000 if unit == 'm' else num * 3600000 if unit == 'h' else num * 86400000
        hadoop_conf.set(entry.getKey(), str(ms_val))

print("✅ Khởi tạo Spark và môi trường hoàn tất!")
# Out:
# ✅ Khởi tạo Spark và môi trường hoàn tất!

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#file parquet nằm trong iceberg-warehouse
df_lemmas = spark.read.table("my_catalog.processed_zone_finnhub.news_lemmas")
df_lemmas.show(5, truncate=False)
# Out:
# +---------+-------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |id       |published_at       |title_lemmas                                                                                     |summary_lemmas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# +---------+-------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |140651233|2026-06-17 09:37:30|[market, chatter, jpmorgan, google, firm, ask, preserve, record, epstein, ranch, investigation]  |[jpmorgan, chase, jpm, alphabet, goog, googl, google, dozen, company]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |140651234|2026-06-17 09:09:41|[uk, regulator, set, new, rule, google, search, boost, competition]                              |[britain, competition, watchdog, order, google, provide, great, transparency, search, ranking, work, new, requirement, aim, secure, fair, deal, business, improve, tech, giant, service, country, require, google, improve, transparency, fairness, search, result, rank, second, require, google, allow, user, search, datum, authorise, party, competition, market, authority, say, statement, wednesday, regulator, flag, concern, google, dominance, search, designate, company, strategic, market, status, allow, set, target, rule, increase, transparency]|
# |140650770|2026-06-17 06:55:00|[google, cloud, model, garden, platform, exclusive, customer, hub, ai, innovation, collaboration]|[google, cloud, summit, london, model, garden, platform, opening, london, year, premier, invitation, google, experience, center, gec, google, strategic, customer, flagship, emea, facility, offer, purpose, build, confidential, environment, suite, executive, senior, leader, partner, learn, drive, digital, transformation, organization, google, cloud, entire, product, portfolio, include, industry, lead, generative, ai, agentic, ai, mod]                                                                                                             |
# |140650768|2026-06-17 06:30:00|[social, medium, political, problem, time, go, away]                                             |[major, country, seek, ban, social, medium, young, user, investor, need, pay, attention]                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |140649980|2026-06-17 03:52:00|[custom, ai, chip, come, nvidia, crown, company, quietly, cash]                                  |[large, cloud, company, design, ai, chip, semiconductor, specialist, capture, fast, grow, slice, spending]                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +---------+-------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from pyspark.sql.functions import col, when, udf
from pyspark.sql.types import FloatType

# Tải bộ từ điển của VADER (Chỉ cần chạy 1 lần trên máy)
# nltk.download('vader_lexicon')

# Khởi tạo công cụ phân tích của VADER
sid = SentimentIntensityAnalyzer()

# 1. Tạo UDF lấy điểm tổng hợp (Compound) của VADER
# Điểm Compound kết hợp tất cả các yếu tố và chuẩn hóa về mức -1.0 đến 1.0
def get_vader_compound(text):
    if text is None or text == "":
        return 0.0
    # Gọi polarity_scores và chỉ trích xuất giá trị 'compound'
    scores = sid.polarity_scores(text)
    return scores['compound']

# Đăng ký UDF
udf_vader = udf(get_vader_compound, FloatType())


#processed
df_processed = df_lemmas \
    .withColumn("title_text", concat_ws(" ", col("title_lemmas"))) \
    .withColumn("summary_text", concat_ws(" ", col("summary_lemmas")))


# 2. Áp dụng UDF lên 2 cột text của bạn (title_text và summary_text)
# Giả sử df_processed là DataFrame đã được nối chuỗi ở bước trước
df_vader = df_processed \
    .withColumn("title_vader_score", udf_vader(col("title_text"))) \
    .withColumn("summary_vader_score", udf_vader(col("summary_text")))

# 3. Phân loại nhãn bằng VADER (Threshold khuyến nghị của chính tác giả VADER)
# Khác với TextBlob, VADER thường dùng mốc 0.05
VADER_POS_THRES = 0.05
VADER_NEG_THRES = -0.05

df_vader = df_vader.withColumn(
    "title_vader_sentiment",
    when(col("title_vader_score") >= VADER_POS_THRES, "Tích cực 🟢")
    .when(col("title_vader_score") <= VADER_NEG_THRES, "Tiêu cực 🔴")
    .otherwise("Trung tính ⚪")
)

df_vader = df_vader.withColumn(
    "summary_vader_sentiment",
    when(col("summary_vader_score") >= VADER_POS_THRES, "Tích cực 🟢")
    .when(col("summary_vader_score") <= VADER_NEG_THRES, "Tiêu cực 🔴")
    .otherwise("Trung tính ⚪")
)

# 4. Hiển thị kết quả
df_vader.select(
    "title_text", 
    "title_vader_score", "title_vader_sentiment",
    "summary_vader_score", "summary_vader_sentiment"
).show(40, truncate=40)
# Out:
# +----------------------------------------+-----------------+---------------------+-------------------+-----------------------+
# |                              title_text|title_vader_score|title_vader_sentiment|summary_vader_score|summary_vader_sentiment|
# +----------------------------------------+-----------------+---------------------+-------------------+-----------------------+
# |market chatter jpmorgan google firm a...|              0.0|         Trung tính ⚪|                0.0|           Trung tính ⚪|
# |uk regulator set new rule google sear...|           0.4019|          Tích cực 🟢|             0.9702|            Tích cực 🟢|
# |google cloud model garden platform ex...|           0.4767|          Tích cực 🟢|             0.1027|            Tích cực 🟢|
# |social medium political problem time ...|          -0.4019|          Tiêu cực 🔴|            -0.6124|            Tiêu cực 🔴|
# |custom ai chip come nvidia crown comp...|              0.0|         Trung tính ⚪|                0.0|           Trung tính ⚪|
# |startup back ex google ceo debuts rob...|              0.0|         Trung tính ⚪|              0.891|            Tích cực 🟢|
# |dow jones futures rise warsh fed debu...|              0.0|         Trung tính ⚪|                0.0|           Trung tính ⚪|
# |hsbc partner google cloud expand ai u...|           0.3182|          Tích cực 🟢|             0.4588|            Tích cực 🟢|
# |voip pal com inc engage veteran consu...|           0.2732|          Tích cực 🟢|             0.4019|            Tích cực 🟢|
# |dow jones hit high spacex keep rise a...|              0.0|         Trung tính ⚪|                0.0|           Trung tính ⚪|
# |nvidia vs alphabet well ai chip stock...|           0.2732|          Tích cực 🟢|             0.4215|            Tích cực 🟢|
# |elon musk keep get rich wealth blow p...|           0.7783|          Tích cực 🟢|              0.802|            Tích cực 🟢|
# |tesla seek customer backing oppose ne...|           0.0258|         Trung tính ⚪|                0.0|           Trung tính ⚪|
# |snap unveil augmented reality glass r...|              0.0|         Trung tính ⚪|             0.4019|            Tích cực 🟢|
# |amazon face penalty potential ftc ad ...|          -0.3182|          Tiêu cực 🔴|            -0.4404|            Tiêu cực 🔴|
# |databrick datum warehouse business hi...|              0.0|         Trung tính ⚪|              0.296|            Tích cực 🟢|
# |battle musk cathie wood sell tesla st...|          -0.3818|          Tiêu cực 🔴|                0.0|           Trung tính ⚪|
# |dell story long pc stock look underva...|              0.0|         Trung tính ⚪|             0.4215|            Tích cực 🟢|
# |oppenheimer pick alphabet dump meta h...|          -0.3818|          Tiêu cực 🔴|                0.0|           Trung tính ⚪|
# |apple inc aapl fall despite ai advanc...|              0.0|         Trung tính ⚪|             0.6486|            Tích cực 🟢|
# |alphabet googl talk samsung manufactu...|              0.0|         Trung tính ⚪|                0.0|           Trung tính ⚪|
# |          way invest anthropic go public|              0.0|         Trung tính ⚪|              0.296|            Tích cực 🟢|
# |palantir stock face hide ai risk goog...|          -0.4215|          Tiêu cực 🔴|             0.7096|            Tích cực 🟢|
# |knotch launch ace ai experience infra...|              0.0|         Trung tính ⚪|             0.5859|            Tích cực 🟢|
# | smh ai capex sustainability gauge crash|          -0.6124|          Tiêu cực 🔴|                0.0|           Trung tính ⚪|
# |        scared big tech ai spending wait|          -0.4404|          Tiêu cực 🔴|                0.0|           Trung tính ⚪|
# |    think dividend worthless reality hit|          -0.4404|          Tiêu cực 🔴|             0.6369|            Tích cực 🟢|
# |uber vs lyft stand strong enter auton...|           0.5106|          Tích cực 🟢|             0.7506|            Tích cực 🟢|
# |spacex overtake nvidia world big company|              0.0|         Trung tính ⚪|              0.875|            Tích cực 🟢|
# |hamm institute awards google support ...|            0.802|          Tích cực 🟢|             0.9694|            Tích cực 🟢|
# |     spacex close amazon sprint trillion|           0.1779|          Tích cực 🟢|                0.0|           Trung tính ⚪|
# |spacex rocket past amazon eye microso...|           0.1779|          Tích cực 🟢|                0.0|           Trung tính ⚪|
# |elon musk lose nearly trillion world ...|           0.2263|          Tích cực 🟢|             0.8225|            Tích cực 🟢|
# |jeff bezos raise billion bet new busi...|           0.2732|          Tích cực 🟢|             0.2732|            Tích cực 🟢|
# |                world second rich person|           0.5574|          Tích cực 🟢|             0.9217|            Tích cực 🟢|
# |ai leader arista network poise hit ne...|              0.0|         Trung tính ⚪|             0.4019|            Tích cực 🟢|
# |ulta beauty expand traditional beauty...|            0.872|          Tích cực 🟢|             0.7783|            Tích cực 🟢|
# |nvidia late big borrower ai datum cen...|          -0.3612|          Tiêu cực 🔴|             0.1531|            Tích cực 🟢|
# |spacex ipo pop signal strong demand a...|           0.4215|          Tích cực 🟢|             0.9231|            Tích cực 🟢|
# |dte energy emerge ai infrastructure b...|           0.6369|          Tích cực 🟢|             0.9001|            Tích cực 🟢|
# +----------------------------------------+-----------------+---------------------+-------------------+-----------------------+
# only showing top 40 rows

# %%
iceberg_table_path = "my_catalog.processed_zone_finnhub.news_VADER_lemmas_sentiment_score"

# Đưa đúng tên biến iceberg_table_path vào saveAsTable
print(f"⏳ Đang ghi dữ liệu vào Apache Iceberg tại bảng: {iceberg_table_path} ...")
df_vader.write \
    .format("iceberg") \
    .mode("overwrite") \
    .saveAsTable(iceberg_table_path)
# Out:
# ⏳ Đang ghi dữ liệu vào Apache Iceberg tại bảng: my_catalog.processed_zone_finnhub.news_VADER_lemmas_sentiment_score ...
